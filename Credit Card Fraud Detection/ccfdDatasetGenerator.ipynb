# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Set random seed for reproducibility
np.random.seed(42)

# Number of transactions
n_transactions = 100000

# Generate features
def generate_creditcard_dataset():
    data = {
        'transaction_id': range(1, n_transactions + 1),
        'transaction_time': np.random.uniform(0, 1, n_transactions),  # normalized time of transaction
        'transaction_amount': np.random.uniform(0.01, 1000, n_transactions),
        'age': np.random.randint(18, 80, n_transactions),
        'gender': np.random.choice(['Male', 'Female'], n_transactions),
        'account_balance': np.random.uniform(0, 10000, n_transactions),
        'transaction_location': np.random.choice(['Online', 'In-store', 'ATM'], n_transactions),
        'transaction_type': np.random.choice(['Purchase', 'Withdrawal', 'Transfer'], n_transactions),
        'card_present': np.random.choice(['Yes', 'No'], n_transactions),
        'repeat_customer': np.random.choice(['Yes', 'No'], n_transactions),
        'merchant_category': np.random.choice(['Retail', 'Travel', 'Food', 'Entertainment'], n_transactions),
        'previous_fraud': np.random.choice(['Yes', 'No'], n_transactions),
        'device_type': np.random.choice(['Mobile', 'Desktop', 'Tablet'], n_transactions),
        'internet_access': np.random.choice(['Yes', 'No'], n_transactions),
    }

    # Create DataFrame
    df = pd.DataFrame(data)

    # Introduce interaction terms
    df['amount_time_interaction'] = df['transaction_amount'] * df['transaction_time']
    df['age_balance_interaction'] = df['age'] * df['account_balance']

    # Generate fraud score (target variable)
    features_for_fraud = ['transaction_time', 'transaction_amount', 'age', 'account_balance', 'amount_time_interaction', 'age_balance_interaction']
    
    # Categorical features
    categorical_features = ['gender', 'transaction_location', 'transaction_type', 'card_present', 'repeat_customer', 'merchant_category', 'previous_fraud', 'device_type', 'internet_access']
    
    # Combine features
    X = df[features_for_fraud + categorical_features]
    
    # Preprocessing pipeline for numeric and categorical features
    numeric_transformer = StandardScaler()
    categorical_transformer = OneHotEncoder()
    
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numeric_transformer, features_for_fraud),
            ('cat', categorical_transformer, categorical_features)])
    
    # Apply the transformations
    X_preprocessed = preprocessor.fit_transform(X)

    # Generate fraud score with minimal randomness
    fraud_score = np.dot(X_preprocessed, np.random.uniform(0.1, 1, X_preprocessed.shape[1])) + np.random.normal(0, 0.1, n_transactions)
    
    # Apply a threshold to create a binary target variable for fraud
    fraud_threshold = np.percentile(fraud_score, 97)  # approximately 3% fraud rate
    df['is_fraud'] = (fraud_score > fraud_threshold).astype(int)

    return df

# Generate the dataset
creditcard_data = generate_creditcard_dataset()

# Save to CSV
creditcard_data.to_csv('creditcard.csv', index=False)

print("Dataset generated and saved as 'creditcard.csv'")
print(creditcard_data.head())
print(creditcard_data.info())
# Out:
# Dataset generated and saved as 'creditcard.csv'
#    transaction_id  transaction_time  transaction_amount  age  gender  \
# 0               1          0.374540          580.783236   25    Male
# 1               2          0.950714          526.976380   58  Female
# 2               3          0.731994          351.043439   71  Female
# 3               4          0.598658          493.217726   27  Female
# 4               5          0.156019          365.102984   28    Male
#
#    account_balance transaction_location transaction_type card_present  \
# 0      3553.081122             In-store       Withdrawal          Yes
# 1      7831.769082             In-store         Transfer          Yes
# 2      2880.461817                  ATM         Transfer          Yes
# 3      1038.626602             In-store         Transfer           No
# 4      5156.680196               Online         Transfer           No
#
#   repeat_customer merchant_category previous_fraud device_type  \
# 0              No     Entertainment             No      Mobile
# 1             Yes            Retail             No      Tablet
# 2             Yes              Food             No     Desktop
# 3              No              Food             No     Desktop
# 4             Yes              Food            Yes     Desktop
#
#   internet_access  amount_time_interaction  age_balance_interaction  is_fraud
# 0             Yes               217.526622             88827.028062         0
# 1             Yes               501.003983            454242.606774         0
# 2             Yes               256.961671            204512.789029         0
# 3              No               295.268976             28042.918265         0
# 4             Yes                56.962871            144387.045477         0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   transaction_id           100000 non-null  int64
#  1   transaction_time         100000 non-null  float64
#  2   transaction_amount       100000 non-null  float64
#  3   age                      100000 non-null  int32
#  4   gender                   100000 non-null  object
#  5   account_balance          100000 non-null  float64
#  6   transaction_location     100000 non-null  object
#  7   transaction_type         100000 non-null  object
#  8   card_present             100000 non-null  object
#  9   repeat_customer          100000 non-null  object
#  10  merchant_category        100000 non-null  object
#  11  previous_fraud           100000 non-null  object
#  12  device_type              100000 non-null  object
#  13  internet_access          100000 non-null  object
#  14  amount_time_interaction  100000 non-null  float64
#  15  age_balance_interaction  100000 non-null  float64
#  16  is_fraud                 100000 non-null  int32
# dtypes: float64(5), int32(2), int64(1), object(9)
# memory usage: 12.2+ MB
# None

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Set random seed for reproducibility
np.random.seed(42)

# Number of transactions
n_transactions = 100000

# Generate features
def generate_creditcard_dataset():
    data = {
        'transaction_id': range(1, n_transactions + 1),
        'transaction_time': np.random.uniform(0, 1, n_transactions),  # normalized time of transaction
        'transaction_amount': np.random.uniform(0.01, 1000, n_transactions),
        'age': np.random.randint(18, 80, n_transactions),
        'gender': np.random.choice(['Male', 'Female'], n_transactions),
        'account_balance': np.random.uniform(0, 10000, n_transactions),
        'transaction_location': np.random.choice(['Online', 'In-store', 'ATM'], n_transactions),
        'transaction_type': np.random.choice(['Purchase', 'Withdrawal', 'Transfer'], n_transactions),
        'card_present': np.random.choice(['Yes', 'No'], n_transactions),
        'repeat_customer': np.random.choice(['Yes', 'No'], n_transactions),
        'merchant_category': np.random.choice(['Retail', 'Travel', 'Food', 'Entertainment'], n_transactions),
        'previous_fraud': np.random.choice(['Yes', 'No'], n_transactions),
        'device_type': np.random.choice(['Mobile', 'Desktop', 'Tablet'], n_transactions),
        'internet_access': np.random.choice(['Yes', 'No'], n_transactions),
    }

    # Create DataFrame
    df = pd.DataFrame(data)

    # Introduce interaction terms
    df['amount_time_interaction'] = df['transaction_amount'] * df['transaction_time']
    df['age_balance_interaction'] = df['age'] * df['account_balance']

    # Generate fraud score (target variable)
    features_for_fraud = ['transaction_time', 'transaction_amount', 'age', 'account_balance', 'amount_time_interaction', 'age_balance_interaction']
    
    # Categorical features
    categorical_features = ['gender', 'transaction_location', 'transaction_type', 'card_present', 'repeat_customer', 'merchant_category', 'previous_fraud', 'device_type', 'internet_access']
    
    # Combine features
    X = df[features_for_fraud + categorical_features]
    
    # Preprocessing pipeline for numeric and categorical features
    numeric_transformer = StandardScaler()
    categorical_transformer = OneHotEncoder()
    
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numeric_transformer, features_for_fraud),
            ('cat', categorical_transformer, categorical_features)])
    
    # Apply the transformations
    X_preprocessed = preprocessor.fit_transform(X)

    # Generate fraud score with minimal randomness
    fraud_score = np.dot(X_preprocessed, np.random.uniform(0.1, 1, X_preprocessed.shape[1])) + np.random.normal(0, 0.1, n_transactions)
    
    # Apply a threshold to create a binary target variable for fraud
    fraud_threshold = np.percentile(fraud_score, 97)  # approximately 3% fraud rate
    df['is_fraud'] = (fraud_score > fraud_threshold).astype(int)

    return df

# Generate the dataset
creditcard_data = generate_creditcard_dataset()

# Save to CSV
creditcard_data.to_csv('prev_creditcard.csv', index=False)

print("Dataset generated and saved as 'prev_creditcard.csv'")
print(creditcard_data.head())
print(creditcard_data.info())
# Out:
# Dataset generated and saved as 'prev_creditcard.csv'
#    transaction_id  transaction_time  transaction_amount  age  gender  \
# 0               1          0.374540          580.783236   25    Male
# 1               2          0.950714          526.976380   58  Female
# 2               3          0.731994          351.043439   71  Female
# 3               4          0.598658          493.217726   27  Female
# 4               5          0.156019          365.102984   28    Male
#
#    account_balance transaction_location transaction_type card_present  \
# 0      3553.081122             In-store       Withdrawal          Yes
# 1      7831.769082             In-store         Transfer          Yes
# 2      2880.461817                  ATM         Transfer          Yes
# 3      1038.626602             In-store         Transfer           No
# 4      5156.680196               Online         Transfer           No
#
#   repeat_customer merchant_category previous_fraud device_type  \
# 0              No     Entertainment             No      Mobile
# 1             Yes            Retail             No      Tablet
# 2             Yes              Food             No     Desktop
# 3              No              Food             No     Desktop
# 4             Yes              Food            Yes     Desktop
#
#   internet_access  amount_time_interaction  age_balance_interaction  is_fraud
# 0             Yes               217.526622             88827.028062         0
# 1             Yes               501.003983            454242.606774         0
# 2             Yes               256.961671            204512.789029         0
# 3              No               295.268976             28042.918265         0
# 4             Yes                56.962871            144387.045477         0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   transaction_id           100000 non-null  int64
#  1   transaction_time         100000 non-null  float64
#  2   transaction_amount       100000 non-null  float64
#  3   age                      100000 non-null  int32
#  4   gender                   100000 non-null  object
#  5   account_balance          100000 non-null  float64
#  6   transaction_location     100000 non-null  object
#  7   transaction_type         100000 non-null  object
#  8   card_present             100000 non-null  object
#  9   repeat_customer          100000 non-null  object
#  10  merchant_category        100000 non-null  object
#  11  previous_fraud           100000 non-null  object
#  12  device_type              100000 non-null  object
#  13  internet_access          100000 non-null  object
#  14  amount_time_interaction  100000 non-null  float64
#  15  age_balance_interaction  100000 non-null  float64
#  16  is_fraud                 100000 non-null  int32
# dtypes: float64(5), int32(2), int64(1), object(9)
# memory usage: 12.2+ MB
# None

# %%
#more  resonable dataset
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Set random seed for reproducibility
np.random.seed(42)

# Number of transactions
n_transactions = 100000

# Generate features
def generate_creditcard_dataset():
    data = {
        'transaction_id': range(1, n_transactions + 1),
        'transaction_time': np.random.uniform(0, 1, n_transactions),  # normalized time of transaction
        'transaction_amount': np.random.uniform(0.01, 1000, n_transactions),
        'age': np.random.randint(18, 80, n_transactions),
        'gender': np.random.choice(['Male', 'Female'], n_transactions),
        'account_balance': np.random.uniform(0, 10000, n_transactions),
        'transaction_location': np.random.choice(['Online', 'In-store', 'ATM'], n_transactions),
        'transaction_type': np.random.choice(['Purchase', 'Withdrawal', 'Transfer'], n_transactions),
        'card_present': np.random.choice(['Yes', 'No'], n_transactions),
        'repeat_customer': np.random.choice(['Yes', 'No'], n_transactions),
        'merchant_category': np.random.choice(['Retail', 'Travel', 'Food', 'Entertainment'], n_transactions),
        'previous_fraud': np.random.choice(['Yes', 'No'], n_transactions),
        'device_type': np.random.choice(['Mobile', 'Desktop', 'Tablet'], n_transactions),
        'internet_access': np.random.choice(['Yes', 'No'], n_transactions),
    }

    # Create DataFrame
    df = pd.DataFrame(data)

    # Introduce interaction terms
    df['amount_time_interaction'] = df['transaction_amount'] * df['transaction_time']
    df['age_balance_interaction'] = df['age'] * df['account_balance']

    # Generate fraud score (target variable)
    features_for_fraud = ['transaction_time', 'transaction_amount', 'age', 'account_balance', 'amount_time_interaction', 'age_balance_interaction']
    
    # Categorical features
    categorical_features = ['gender', 'transaction_location', 'transaction_type', 'card_present', 'repeat_customer', 'merchant_category', 'previous_fraud', 'device_type', 'internet_access']
    
    # Combine features
    X = df[features_for_fraud + categorical_features]
    
    # Preprocessing pipeline for numeric and categorical features
    numeric_transformer = StandardScaler()
    categorical_transformer = OneHotEncoder()
    
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numeric_transformer, features_for_fraud),
            ('cat', categorical_transformer, categorical_features)])
    
    # Apply the transformations
    X_preprocessed = preprocessor.fit_transform(X)

    # Generate fraud score with adjusted randomness
    fraud_score = (np.dot(X_preprocessed, np.random.uniform(0.1, 0.5, X_preprocessed.shape[1])) 
                   + np.random.normal(0, 0.5, n_transactions))
    
    # Apply a threshold to create a binary target variable for fraud
    fraud_threshold = np.percentile(fraud_score, 95)  # approximately 5% fraud rate
    df['is_fraud'] = (fraud_score > fraud_threshold).astype(int)

    return df

# Generate the dataset
creditcard_data = generate_creditcard_dataset()

# Save to CSV
creditcard_data.to_csv('updated_creditcard.csv', index=False)

print("Dataset generated and saved as 'updated_creditcard.csv'")
print(creditcard_data.head())
print(creditcard_data.info())
# Out:
# Dataset generated and saved as 'updated_creditcard.csv'
#    transaction_id  transaction_time  transaction_amount  age  gender  \
# 0               1          0.374540          580.783236   25    Male
# 1               2          0.950714          526.976380   58  Female
# 2               3          0.731994          351.043439   71  Female
# 3               4          0.598658          493.217726   27  Female
# 4               5          0.156019          365.102984   28    Male
#
#    account_balance transaction_location transaction_type card_present  \
# 0      3553.081122             In-store       Withdrawal          Yes
# 1      7831.769082             In-store         Transfer          Yes
# 2      2880.461817                  ATM         Transfer          Yes
# 3      1038.626602             In-store         Transfer           No
# 4      5156.680196               Online         Transfer           No
#
#   repeat_customer merchant_category previous_fraud device_type  \
# 0              No     Entertainment             No      Mobile
# 1             Yes            Retail             No      Tablet
# 2             Yes              Food             No     Desktop
# 3              No              Food             No     Desktop
# 4             Yes              Food            Yes     Desktop
#
#   internet_access  amount_time_interaction  age_balance_interaction  is_fraud
# 0             Yes               217.526622             88827.028062         0
# 1             Yes               501.003983            454242.606774         0
# 2             Yes               256.961671            204512.789029         0
# 3              No               295.268976             28042.918265         0
# 4             Yes                56.962871            144387.045477         0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   transaction_id           100000 non-null  int64
#  1   transaction_time         100000 non-null  float64
#  2   transaction_amount       100000 non-null  float64
#  3   age                      100000 non-null  int32
#  4   gender                   100000 non-null  object
#  5   account_balance          100000 non-null  float64
#  6   transaction_location     100000 non-null  object
#  7   transaction_type         100000 non-null  object
#  8   card_present             100000 non-null  object
#  9   repeat_customer          100000 non-null  object
#  10  merchant_category        100000 non-null  object
#  11  previous_fraud           100000 non-null  object
#  12  device_type              100000 non-null  object
#  13  internet_access          100000 non-null  object
#  14  amount_time_interaction  100000 non-null  float64
#  15  age_balance_interaction  100000 non-null  float64
#  16  is_fraud                 100000 non-null  int32
# dtypes: float64(5), int32(2), int64(1), object(9)
# memory usage: 12.2+ MB
# None

# %%
#Ultra Updated dataset
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Set random seed for reproducibility
np.random.seed(42)

# Number of transactions
n_transactions = 100000

# Generate features
def generate_creditcard_dataset():
    data = {
        'transaction_id': range(1, n_transactions + 1),
        'transaction_time': np.random.uniform(0, 1, n_transactions),  # normalized time of transaction
        'transaction_amount': np.random.uniform(0.01, 1000, n_transactions),
        'age': np.random.randint(18, 80, n_transactions),
        'gender': np.random.choice(['Male', 'Female'], n_transactions),
        'account_balance': np.random.uniform(0, 10000, n_transactions),
        'transaction_location': np.random.choice(['Online', 'In-store', 'ATM'], n_transactions),
        'transaction_type': np.random.choice(['Purchase', 'Withdrawal', 'Transfer'], n_transactions),
        'card_present': np.random.choice(['Yes', 'No'], n_transactions),
        'repeat_customer': np.random.choice(['Yes', 'No'], n_transactions),
        'merchant_category': np.random.choice(['Retail', 'Travel', 'Food', 'Entertainment'], n_transactions),
        'previous_fraud': np.random.choice(['Yes', 'No'], n_transactions),
        'device_type': np.random.choice(['Mobile', 'Desktop', 'Tablet'], n_transactions),
        'internet_access': np.random.choice(['Yes', 'No'], n_transactions),
    }

    # Create DataFrame
    df = pd.DataFrame(data)

    # Introduce interaction terms
    df['amount_time_interaction'] = df['transaction_amount'] * df['transaction_time']
    df['age_balance_interaction'] = df['age'] * df['account_balance']

    # Generate fraud score (target variable)
    features_for_fraud = ['transaction_time', 'transaction_amount', 'age', 'account_balance', 'amount_time_interaction', 'age_balance_interaction']
    
    # Categorical features
    categorical_features = ['gender', 'transaction_location', 'transaction_type', 'card_present', 'repeat_customer', 'merchant_category', 'previous_fraud', 'device_type', 'internet_access']
    
    # Combine features
    X = df[features_for_fraud + categorical_features]
    
    # Preprocessing pipeline for numeric and categorical features
    numeric_transformer = StandardScaler()
    categorical_transformer = OneHotEncoder()
    
    preprocessor = ColumnTransformer(
        transformers=[
            ('num', numeric_transformer, features_for_fraud),
            ('cat', categorical_transformer, categorical_features)])
    
    # Apply the transformations
    X_preprocessed = preprocessor.fit_transform(X)

    # Generate fraud score with further adjusted randomness
    fraud_score = (np.dot(X_preprocessed, np.random.uniform(0.05, 0.3, X_preprocessed.shape[1])) 
                   + np.random.normal(0, 1, n_transactions))
    
    # Apply a threshold to create a binary target variable for fraud
    fraud_threshold = np.percentile(fraud_score, 92)  # approximately 8% fraud rate
    df['is_fraud'] = (fraud_score > fraud_threshold).astype(int)

    return df

# Generate the dataset
creditcard_data = generate_creditcard_dataset()

# Save to CSV
creditcard_data.to_csv('NUcreditcard.csv', index=False)

print("Dataset generated and saved as 'NUcreditcard.csv'")
print(creditcard_data.head())
print(creditcard_data.info())
# Out:
# Dataset generated and saved as 'NUcreditcard.csv'
#    transaction_id  transaction_time  transaction_amount  age  gender  \
# 0               1          0.374540          580.783236   25    Male
# 1               2          0.950714          526.976380   58  Female
# 2               3          0.731994          351.043439   71  Female
# 3               4          0.598658          493.217726   27  Female
# 4               5          0.156019          365.102984   28    Male
#
#    account_balance transaction_location transaction_type card_present  \
# 0      3553.081122             In-store       Withdrawal          Yes
# 1      7831.769082             In-store         Transfer          Yes
# 2      2880.461817                  ATM         Transfer          Yes
# 3      1038.626602             In-store         Transfer           No
# 4      5156.680196               Online         Transfer           No
#
#   repeat_customer merchant_category previous_fraud device_type  \
# 0              No     Entertainment             No      Mobile
# 1             Yes            Retail             No      Tablet
# 2             Yes              Food             No     Desktop
# 3              No              Food             No     Desktop
# 4             Yes              Food            Yes     Desktop
#
#   internet_access  amount_time_interaction  age_balance_interaction  is_fraud
# 0             Yes               217.526622             88827.028062         0
# 1             Yes               501.003983            454242.606774         0
# 2             Yes               256.961671            204512.789029         0
# 3              No               295.268976             28042.918265         0
# 4             Yes                56.962871            144387.045477         0
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   transaction_id           100000 non-null  int64
#  1   transaction_time         100000 non-null  float64
#  2   transaction_amount       100000 non-null  float64
#  3   age                      100000 non-null  int32
#  4   gender                   100000 non-null  object
#  5   account_balance          100000 non-null  float64
#  6   transaction_location     100000 non-null  object
#  7   transaction_type         100000 non-null  object
#  8   card_present             100000 non-null  object
#  9   repeat_customer          100000 non-null  object
#  10  merchant_category        100000 non-null  object
#  11  previous_fraud           100000 non-null  object
#  12  device_type              100000 non-null  object
#  13  internet_access          100000 non-null  object
#  14  amount_time_interaction  100000 non-null  float64
#  15  age_balance_interaction  100000 non-null  float64
#  16  is_fraud                 100000 non-null  int32
# dtypes: float64(5), int32(2), int64(1), object(9)
# memory usage: 12.2+ MB
# None
